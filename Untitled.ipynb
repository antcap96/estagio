# %% [markdown]
# # NN

# %%
import matplotlib

import pandas
import matplotlib.pyplot as plt
import numpy as np

from math import sqrt, exp

# %matplotlib inline

from scipy.optimize import curve_fit

# %% [markdown]
# ## Skim size, Acceptance and xSec

# %%
signalFullSize = [50000, 50000, 49600, 50000, 50000, 50000, 100000, 100000, 100000, 99800]
signalSkimSize = [403, 394, 390, 372, 479, 655, 1619, 1858, 2008, 2239]
signalXSec = [33.57, 45.01, 52.45, 61.85, 67.52, 76.71, 76.71, 78.36, 77.79, 76.64, 73.27]
signalAcceptance = [a/b for a,b in zip(signalSkimSize, signalFullSize)]

allSignalFullSize = sum(signalFullSize)
allSignalSkimSize = sum(signalSkimSize)
allSignalAcceptance = allSignalSkimSize/allSignalFullSize

backgroundFullSize = [92925926, 47502020]
backgroundSkimSize = [166157, 1896]
backgroundXSec = [816, 4220]
backgroundAcceptance = [a/b for a,b in zip(backgroundSkimSize, backgroundFullSize)]

allBackgroundFullSize = sum(backgroundFullSize)
allBackgroundSkimSize = sum(backgroundSkimSize)
allBackGroundAcceptance = allBackgroundSkimSize/allBackgroundFullSize

# %% [markdown]
# ## import data from root files

# %%
loc = './Data/'

energies = [260, 270, 280, 300, 320, 400, 500, 550, 600, 700]

signalData = []
backgroundData = []

for energy in energies:
    signalData.append(pandas.read_csv(loc + "GluGluToRadionToHHTo2B2Tau_M-" + str(energy) +"_narrow_13TeV-madgraph.csv"))

#backgroundData.append(pandas.read_csv(loc + "TT_TuneCUETP8M1_13TeV-powheg-pythia8_1.csv")) # same as 2 but only the first half of the events
backgroundData.append(pandas.read_csv(loc + "TT_TuneCUETP8M1_13TeV-powheg-pythia8_2.csv"))
backgroundData.append(pandas.read_csv(loc + "WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8.csv"))


# drop columns without header
for signal_data in signalData:
    signal_data.drop([x for x in signal_data.columns if 'Unnamed' in x], axis=1, inplace=True)

for background_data in backgroundData:
    background_data.drop([x for x in background_data.columns if 'Unnamed' in x], axis=1, inplace=True)

allSignalData = signalData[0]
for signal_data in signalData[1:]:
    allSignalData = allSignalData.append(signal_data, ignore_index=True)

allBackgroundData = backgroundData[0]
for background_data in backgroundData[1:]:
    allBackgroundData = allBackgroundData.append(background_data, ignore_index=True)

for i in range(len(energies)):
    print("{} events for Higgs with {} GeV".format(len(signalData[i]), energies[i]))
print("{} TT_Tune events".format(len(backgroundData[0])))
print("{} WJetsToLNu_Tune events".format(len(backgroundData[1])), end='\n\n')
print("{} events of Higgs".format(len(allSignalData)))
print("{} background events".format(len(allBackgroundData)))
# Out:
# 403 events for Higgs with 260 GeV
# 394 events for Higgs with 270 GeV
# 390 events for Higgs with 280 GeV
# 372 events for Higgs with 300 GeV
# 479 events for Higgs with 320 GeV
# 655 events for Higgs with 400 GeV
# 1619 events for Higgs with 500 GeV
# 1858 events for Higgs with 550 GeV
# 2008 events for Higgs with 600 GeV
# 2239 events for Higgs with 700 GeV
# 166157 TT_Tune events
# 1896 WJetsToLNu_Tune events
#
# 10417 events of Higgs
# 168053 background events

# %% [markdown]
# ### Calculate significância

# %%
def calculateFOM(Signals, Backgounds, signalIdx=range(len(signalData)), backgroundIdx=range(len(backgroundData))):
    s_signal, s_background = 0, 0
    for i, signal in enumerate(Signals):
        s_signal += len(signal) * signalXSec[signalIdx[i]] / signalFullSize[signalIdx[i]]
    
    for i, background in enumerate(Backgounds):
        s_background += len(background) * backgroundXSec[backgroundIdx[i]] / backgroundFullSize[backgroundIdx[i]]
    
    return s_signal / sqrt(s_background)

# %%
# Indexes to merge and analise
signalIdx = [0]
backgroundIdx = range(len(backgroundData))
    
# Create a new variable with the data to analise
signalAnal = [signalData[i] for i in signalIdx]
backgroundAnal = [backgroundData[i] for i in backgroundIdx]

# Data to analise all merged
allSignalAnal = signalAnal[0]
for i in range(1, len(signalAnal)):
    allSignalAnal = allSignalAnal.append(signalAnal[i], ignore_index=True)
    
allBackgroundAnal = backgroundAnal[0]
for i in range(1, len(backgroundAnal)):
    allBackgroundAnal = allBackgroundAnal.append(backgroundAnal[i], ignore_index=True)


# Variables to create the cuts
signalSelector = [pandas.Series([True for i in range(len(signalAnal[i]))]) for i in range(len(signalAnal))]
backgroundSelector = [pandas.Series([True for i in range(len(backgroundAnal[i]))]) for i in range(len(backgroundAnal))]

#
# Add conditions here:
#
for i in range(len(signalSelector)):
    signalSelector[i] = signalSelector[i] & (((signalAnal[i]['h_bb_mass']-116)/35)**2 + ((signalAnal[i]['h_tt_mass']-111)/45)**2 < 1)

for i in range(len(backgroundSelector)):
    backgroundSelector[i] = backgroundSelector[i] & (((backgroundAnal[i]['h_bb_mass']-116)/35)**2 + ((backgroundAnal[i]['h_tt_mass']-111)/45)**2 < 1)

# Data after cuts
cutSignalAnal, cutBackgroundAnal = [], []

for i in range(len(signalAnal)):
    cutSignalAnal.append(signalAnal[i][signalSelector[i]])
    
for i in range(len(backgroundAnal)):
    cutBackgroundAnal.append(backgroundAnal[i][backgroundSelector[i]])

# Data after cuts merged
allCutSignalAnal = cutSignalAnal[0]
for i in range(1, len(signalAnal)):
    allCutSignalAnal = allCutSignalAnal.append(cutSignalAnal[i], ignore_index=True)
    
allCutBackgroundAnal = cutBackgroundAnal[0]
for i in range(1, len(backgroundAnal)):
    allCutBackgroundAnal = allCutBackgroundAnal.append(cutBackgroundAnal[i], ignore_index=True)
    
print("{} events for signal and {} events for background".format(len(allCutSignalAnal), len(allCutBackgroundAnal)))
print("original: {} events for signal and {} events for background".format(len(allSignalAnal), len(allBackgroundAnal)))

print("FOM is: {:.6}".format(calculateFOM(cutSignalAnal, cutBackgroundAnal, signalIdx, backgroundIdx)))
print("FOM with no cuts is: {:.6}".format(calculateFOM(signalAnal, backgroundAnal, signalIdx, backgroundIdx)))
# Out:
# 219 events for signal and 23149 events for background
# original: 403 events for signal and 168053 events for background
# FOM is: 0.309615
# FOM with no cuts is: 0.212093

# %%
#normalize data for ploting

weightsSignal = []
for i, idx in enumerate(signalIdx):
    weightsSignal.append(1/signalFullSize[idx] * signalXSec[idx])

weightsBackground = []
for i, idx in enumerate(backgroundIdx):
    weightsBackground.append(1/backgroundFullSize[idx]*backgroundXSec[idx])

# weights for data without cuts

weightSignal = np.empty(0)
for i in range(len(signalAnal)):
    weightSignal = np.append(weightSignal, np.full(len(signalAnal[i]), weightsSignal[i]))
    
weightBackground = np.empty(0)
for i in range(len(backgroundAnal)):
    weightBackground = np.append(weightBackground, np.full(len(backgroundAnal[i]), weightsBackground[i]))
    
# weights for data with cuts

weightCutSignal = np.empty(0)
for i in range(len(signalAnal)):
    weightCutSignal = np.append(weightCutSignal, np.full(len(cutSignalAnal[i]), weightsSignal[i]))
    
weightCutBackground = np.empty(0)
for i in range(len(backgroundAnal)):
    weightCutBackground = np.append(weightCutBackground, np.full(len(cutBackgroundAnal[i]), weightsBackground[i]))
    
# signal/background ratio (used to normalize histogram if wanted)
weightRatio = sum(weightSignal)/sum(weightBackground)
weightCutRatio = sum(weightCutSignal)/sum(weightCutBackground)

# %%
fig = plt.figure(figsize=(16, 16))

normalizeSignalBackground = True

if normalizeSignalBackground:
    weightsCut = [weightCutSignal, weightCutBackground*weightCutRatio]
    weights = [weightSignal, weightBackground*weightRatio]
else:
    weightsCut = [weightCutSignal, weightCutBackground]
    weights = [weightSignal, weightBackground]

to_analise = ['h_bb_eta', 'h_bb_mass', 'h_bb_pT', 'h_tt_eta', 'h_tt_mass', 'h_tt_pT']

for i, var_to_analise in enumerate(to_analise):
    bins = np.linspace(min(allBackgroundData[var_to_analise]), max(allBackgroundData[var_to_analise]), 100)
    
    fig.add_subplot(len(to_analise),2,2*i+1)
    
    histData = [allCutSignalAnal[var_to_analise], allCutBackgroundAnal[var_to_analise]]
    plt.hist(histData, bins=bins, stacked=True, label=["signal", "background"], weights=weightsCut, normed=True)
    plt.title(var_to_analise)
    plt.legend(fontsize=16)
    
    fig.add_subplot(len(to_analise),2,2*i+2)
    
    allHistData = [allSignalAnal[var_to_analise], allBackgroundAnal[var_to_analise]]
    plt.hist(allHistData, bins=bins, stacked=True, label=["signal", "background"], weights=weights, normed=True)
    plt.title(var_to_analise)
    plt.legend(fontsize=16)
    
plt.show()

# %%
def gaussian(x, amp, x0, sig):
    return amp * np.exp(-(x-x0)**2 /sig)

#y, x = np.histogram(signalData[0]['h_bb_mass'],50)

#xdata = 0.5*(x[1:] + x[:-1])

#xdata= xdata[:-40]
#ynew = y[:-40]

#print(xdata)

#print(len(x),len(y), sep='\n')

#best_vals, covar = curve_fit(gaussian, xdata, ynew, p0=[66, 110, 30])

#plt.plot(xdata, gaussian(xdata, *best_vals), color="r", label='fit')
#plt.bar(x[:-1], y, width=x[1]-x[0])

#print(best_vals)
# Out:
# [  24.75011404   36.87512713   49.00014022   61.12515331   73.2501664
#    85.3751795    97.50019259  109.62520568  121.75021877  133.87523186]
# 51
# 50
# [   65.61192221   103.20316156  1404.73291904]
